# %%
#Libraries
import pandas as pd
import json

from pathlib import Path

# %% [markdown]
# Load The JSON File

# %%
with open("../data/orders.json", "r") as file:
    orders_data = json.load(file)

# %% [markdown]
# Structure Of JSON

# %%
type(orders_data)
# Out:
# list

# %%
len(orders_data)
# Out:
# 25000

# %%
orders_data[0]
# Out:
# {'order_id': '8174c2af-07a4-4837-9068-1169d963e36e',
#  'restaurant_name': 'TBC Sky Lounge',
#  'order_date': '2025-05-06',
#  'order_value': 201.87,
#  'discount_used': 'No',
#  'payment_method': 'Card'}

# %% [markdown]
# Convert JSON to DataFrame

# %%
orders_df = pd.DataFrame(orders_data)

# %%
orders_df.head()
# Out:
#                                order_id          restaurant_name  order_date  \
# 0  8174c2af-07a4-4837-9068-1169d963e36e           TBC Sky Lounge  2025-05-06
# 1  0f9ddb57-4632-4a9f-9afe-1d2e41b94e32  KC Das - Sweet Paradise  2026-01-08
# 2  099deda6-8c53-41cb-abf8-00126e6b2643        Hotel Kadamba Veg  2026-01-22
# 3  94a6ba27-d6ef-4d10-a026-ac0c0afa8505            Cafe Srinidhi  2025-11-10
# 4  216f3ec7-80a9-4d95-872f-715c37163b6d                   Pebble  2025-12-22
#
#    order_value discount_used payment_method
# 0       201.87            No           Card
# 1      1392.27            No           Cash
# 2      1358.35           Yes            UPI
# 3       782.37            No            UPI
# 4      1551.09           Yes            UPI

# %% [markdown]
# Explore the data

# %%
orders_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         25000 non-null  str
#  1   restaurant_name  25000 non-null  str
#  2   order_date       25000 non-null  str
#  3   order_value      25000 non-null  float64
#  4   discount_used    25000 non-null  str
#  5   payment_method   25000 non-null  str
# dtypes: float64(1), str(5)
# memory usage: 2.8 MB

# %%
orders_df.shape
# Out:
# (25000, 6)

# %%
orders_df.describe(include='all')
# Out:
#                                     order_id restaurant_name  order_date  \
# count                                  25000           25000       25000
# unique                                 25000            3159         301
# top     8174c2af-07a4-4837-9068-1169d963e36e       Cake Cafe  2025-05-16
# freq                                       1              19         113
# mean                                     NaN             NaN         NaN
# std                                      NaN             NaN         NaN
# min                                      NaN             NaN         NaN
# 25%                                      NaN             NaN         NaN
# 50%                                      NaN             NaN         NaN
# 75%                                      NaN             NaN         NaN
# max                                      NaN             NaN         NaN
#
#          order_value discount_used payment_method
# ...

# %%
orders_df.columns
# Out:
# Index(['order_id', 'restaurant_name', 'order_date', 'order_value',
#        'discount_used', 'payment_method'],
#       dtype='str')

# %%
orders_df.isnull().sum()
# Out:
# order_id           0
# restaurant_name    0
# order_date         0
# order_value        0
# discount_used      0
# payment_method     0
# dtype: int64

# %%
orders_df.isna().sum()
# Out:
# order_id           0
# restaurant_name    0
# order_date         0
# order_value        0
# discount_used      0
# payment_method     0
# dtype: int64

# %%
orders_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Cleaning restaurant name column
#     - Removing extra space

# %%
orders_df['restaurant_name'] = orders_df['restaurant_name'].str.strip()

# %% [markdown]
# # Cleaning Orders Date Column
#     - Changing Data Type

# %%
orders_df['order_date'] = pd.to_datetime(orders_df['order_date'])

# %% [markdown]
# # Cleaning discount_used Column
#     - Checking Unique Value

# %%
orders_df['discount_used'].unique()
# Out:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %% [markdown]
# # Cleaning payment_method Column
#     - Checking Unique Value

# %%
orders_df['payment_method'].unique()
# Out:
# <ArrowStringArray>
# ['Card', 'Cash', 'UPI']
# Length: 3, dtype: str

# %% [markdown]
# # Verify

# %%
orders_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         25000 non-null  str
#  1   restaurant_name  25000 non-null  str
#  2   order_date       25000 non-null  datetime64[us]
#  3   order_value      25000 non-null  float64
#  4   discount_used    25000 non-null  str
#  5   payment_method   25000 non-null  str
# dtypes: datetime64[us](1), float64(1), str(4)
# memory usage: 2.6 MB

# %% [markdown]
# Save the cleaned orders

# %%
orders_df.to_csv("../data/orders_cleaned.csv", index=False)

print("Orders Data Cleaning done and Cleaned CSV saved successfully")
# Out:
# Orders Data Cleaning done and Cleaned CSV saved successfully

# %%
orders_df.head()
# Out:
#                                order_id          restaurant_name order_date  \
# 0  8174c2af-07a4-4837-9068-1169d963e36e           TBC Sky Lounge 2025-05-06
# 1  0f9ddb57-4632-4a9f-9afe-1d2e41b94e32  KC Das - Sweet Paradise 2026-01-08
# 2  099deda6-8c53-41cb-abf8-00126e6b2643        Hotel Kadamba Veg 2026-01-22
# 3  94a6ba27-d6ef-4d10-a026-ac0c0afa8505            Cafe Srinidhi 2025-11-10
# 4  216f3ec7-80a9-4d95-872f-715c37163b6d                   Pebble 2025-12-22
#
#    order_value discount_used payment_method
# 0       201.87            No           Card
# 1      1392.27            No           Cash
# 2      1358.35           Yes            UPI
# 3       782.37            No            UPI
# 4      1551.09           Yes            UPI
